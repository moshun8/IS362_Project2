# %% [markdown]
# # Cause of Death Data

# %%
import pandas as pd
import numpy as np

death = pd.read_csv('https://raw.githubusercontent.com/moshun8/IS362_Project2/master/Project2_causeofdeath.csv')
#death = pd.read_csv('/Users/Maureen/Desktop/GitHub/IS362_Project2/Project2_causeofdeath.csv')
death.head()
# Out:
#    Year                              Leading Cause Sex         Race Ethnicity  \
# 0  2014                Diabetes Mellitus (E10-E14)   F  Other Race/ Ethnicity
# 1  2011  Cerebrovascular Disease (Stroke: I60-I69)   M     White Non-Hispanic
# 2  2008      Malignant Neoplasms (Cancer: C00-C97)   M     Not Stated/Unknown
# 3  2010      Malignant Neoplasms (Cancer: C00-C97)   F               Hispanic
# 4  2012  Cerebrovascular Disease (Stroke: I60-I69)   M     Black Non-Hispanic
#
#   Deaths Death Rate Age Adjusted Death Rate
# 0     11          .                       .
# 1    290       21.7                    18.2
# 2     60          .                       .
# 3   1045       85.9                    98.5
# 4    170       19.9                    23.3

# %% [markdown]
# 1. Change column names
# 2. replace cells with "." with NaN
# 3. Sort and assign new index

# %%
column_names = {'Year': 'year', 
                'Leading Cause': 'cause',
                'Sex': 'sex', 
                'Race Ethnicity': 'race', 
                'Deaths': 'deaths',
                'Death Rate': 'death_rate', 
                'Age Adjusted Death Rate': 'adj_dr'}

death = (death.rename(columns=column_names)
         .replace('.', np.nan))
#death['id'] = death.index

death_sort = (death
         .sort_values(by=['year','cause','race','sex'])
         .set_index(['cause','year','race']))
death_sort.head(30)
# Out:
#                                                                                    sex  \
# cause                                              year race
# Accidents Except Drug Posioning (V01-X39, X43, ... 2007 Asian and Pacific Islander   F
#                                                         Asian and Pacific Islander   M
#                                                         Black Non-Hispanic           F
#                                                         Black Non-Hispanic           M
#                                                         Hispanic                     F
#                                                         Hispanic                     M
#                                                         Not Stated/Unknown           F
#                                                         Not Stated/Unknown           M
#                                                         Other Race/ Ethnicity        F
#                                                         Other Race/ Ethnicity        M
#                                                         White Non-Hispanic           F
#                                                         White Non-Hispanic           M
# All Other Causes                                   2007 Asian and Pacific Islander   F
#                                                         Asian and Pacific Islander   M
#                                                         Black Non-Hispanic           F
#                                                         Black Non-Hispanic           M
#                                                         Hispanic                     F
#                                                         Hispanic                     M
#                                                         Not Stated/Unknown           F
#                                                         Not Stated/Unknown           M
#                                                         Other Race/ Ethnicity        F
#                                                         Other Race/ Ethnicity        M
#                                                         White Non-Hispanic           F
#                                                         White Non-Hispanic           M
# Alzheimer's Disease (G30)                          2007 Not Stated/Unknown           F
#                                                         White Non-Hispanic           F
# Aortic Aneurysm and Dissection (I71)               2007 Not Stated/Unknown           F
# Assault (Homicide: Y87.1, X85-Y09)                 2007 Black Non-Hispanic           M
#                                                         Hispanic                     M
#                                                         Not Stated/Unknown           M
#
#                                                                                    deaths  \
# cause                                              year race
# Accidents Except Drug Posioning (V01-X39, X43, ... 2007 Asian and Pacific Islander     32
#                                                         Asian and Pacific Islander     53
#                                                         Black Non-Hispanic             87
#                                                         Black Non-Hispanic            158
#                                                         Hispanic                       71
#                                                         Hispanic                      154
#                                                         Not Stated/Unknown            NaN
#                                                         Not Stated/Unknown              8
#                                                         Not Stated/Unknown            NaN
#                                                         Other Race/ Ethnicity         NaN
#                                                         Other Race/ Ethnicity         NaN
#                                                         White Non-Hispanic           81.5
#                                                         White Non-Hispanic          115.9
# Alzheimer's Disease (G30)                          2007 Not Stated/Unknown            NaN
#                                                         White Non-Hispanic            3.5
# Aortic Aneurysm and Dissection (I71)               2007 Not Stated/Unknown            NaN
# Assault (Homicide: Y87.1, X85-Y09)                 2007 Black Non-Hispanic           31.1
#                                                         Hispanic                      9.9
#                                                         Not Stated/Unknown            NaN

# %% [markdown]
# ### Check column types

# %%
death.dtypes
# Out:
# year           int64
# cause         object
# sex           object
# race          object
# deaths        object
# death_rate    object
# adj_dr        object
# dtype: object

# %% [markdown]
# ### Check the datatypes of columns then change the ones that should be numerical to the correct format.

# %%
death = death.apply(lambda x: pd.to_numeric(x, errors='ignore'))
death.dtypes
# Out:
# year            int64
# cause          object
# sex            object
# race           object
# deaths        float64
# death_rate    float64
# adj_dr        float64
# dtype: object

# %% [markdown]
# ### Make sure there aren't any duplicates

# %%
death = death.drop_duplicates()

# %% [markdown]
# ### See the average adjusted death rate by year for each race

# %%
death_sum = pd.DataFrame(death.groupby(['year','race']).adj_dr.mean())
death_sum.head(30)
# Out:
#                                     adj_dr
# year race
# 2007 Asian and Pacific Islander  35.840909
#      Black Non-Hispanic          70.225000
#      Hispanic                    53.068182
#      Not Stated/Unknown                NaN
#      Other Race/ Ethnicity             NaN
#      White Non-Hispanic          64.140909
# 2008 Asian and Pacific Islander  34.104348
#      Black Non-Hispanic          74.240909
#      Hispanic                    54.109091
#      Not Stated/Unknown                NaN
#      Other Race/ Ethnicity             NaN
#      White Non-Hispanic          63.504545
# 2009 Asian and Pacific Islander  34.468182
#      Black Non-Hispanic          71.636364
#      Hispanic                    49.382609
#      Not Stated/Unknown                NaN
#      Other Race/ Ethnicity             NaN
#      White Non-Hispanic          61.204545
# 2010 Asian and Pacific Islander  33.936364
#      Black Non-Hispanic          70.454545
#      Hispanic                    50.977273
#      Not Stated/Unknown                NaN
#      Other Race/ Ethnicity             NaN
#      White Non-Hispanic          59.900000
# 2011 Asian and Pacific Islander  34.945455
#      Black Non-Hispanic          69.872727
#      Hispanic                    49.368182
#      Not Stated/Unknown                NaN
#      Other Race/ Ethnicity             NaN
#      White Non-Hispanic          59.695455

# %% [markdown]
# ### Unstacking makes it easier to see trends by race. Also, deleting columns with all NaN values gets rid of unecessary info.

# %%
death_sum.unstack().dropna(how='all', axis=1)
# Out:
#                          adj_dr                                \
# race Asian and Pacific Islander Black Non-Hispanic   Hispanic
# year
# 2007                  35.840909          70.225000  53.068182
# 2008                  34.104348          74.240909  54.109091
# 2009                  34.468182          71.636364  49.382609
# 2010                  33.936364          70.454545  50.977273
# 2011                  34.945455          69.872727  49.368182
# 2012                  34.100000          68.481818  47.990909
# 2013                  33.963636          66.663636  47.731818
# 2014                  33.750000          64.936364  45.986364
#
#
# race White Non-Hispanic
# year
# 2007          64.140909
# 2008          63.504545
# 2009          61.204545
# 2010          59.900000
# 2011          59.695455
# 2012          57.886364
# 2013          57.340909
# 2014          56.427273
